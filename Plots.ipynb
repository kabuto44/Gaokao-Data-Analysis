# %%
#import libraries
import numpy as np
import matplotlib.pyplot as plt
import csv
import operations as ops
import consts as const

# %%
def plot_all(indicator):
    for i in range(len(const.CATEGORIES)):
        category = const.CATEGORIES(i)
        name = const.CATEGORY_NAMES(i)
        ops.singleplot(indicator,category,title=indicator+ ", " + name)

# %%
ops.saveplot(name="Undergraduate Attrition by Senior Size",variable="Undergraduate Attrition by Senior Size")

# %%
ops.singleplot("Undergraduate Attrition by Senior Size")

# %%
ops.singleplot("Undergraduate Attrition by Senior Size",provinces=const.NORTH_CHINA)

# %%
ops.singleplot("Undergraduate Attrition by Senior Size",provinces=const.NORTH_CHINA_MINUS_CITIES)

# %%
ops.singleplot("Undergraduate Attrition by Senior Size",provinces=const.NORTHEAST)

# %%
ops.singleplot("Undergraduate Attrition by Senior Size",provinces=const.EAST_CHINA)

# %%
ops.singleplot("Undergraduate Attrition by Senior Size",provinces=const.EAST_CHINA_MINUS_CITIES)

# %%
ops.singleplot("Undergraduate Attrition by Senior Size",provinces=const.CENTRAL_CHINA)

# %%
ops.singleplot("Undergraduate Attrition by Senior Size",provinces=const.NORTHWEST)

# %%
ops.singleplot("Undergraduate Attrition by Senior Size",provinces=const.SOUTHWEST)
