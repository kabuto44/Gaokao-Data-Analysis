# %%
#import libraries
import numpy as np
import matplotlib.pyplot as plt
import csv
import operations as ops
import consts as const

# %%
ops.singleplot("ST Ratio Vocational Secondary")

# %%
#define interface variables
provinces = []
datasets = []

# %%
def multiplot(title = None, ylabel = None,legend=True):
    ops.multiplot(datasets,provinces,title,ylabel,legend_on=legend)

# %%
provinces = ["Inner Mongolia", "Jilin", "Ningxia", "Hainan", "Tianjin", "Beijing"]
datasets = ["Secondary Senior Graduates"]
# multiplot(ylabel = "10,000 people")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 provinces = ["Inner Mongolia", "Jilin", "Ningxia", "Hainan", "Tianjin", "Beijing"]
#       2 datasets = ["Secondary Senior Graduates"]
# ----> 3 multiplot(ylabel = "10,000 people")
#
# Cell In[4], line 2, in multiplot(title, ylabel, legend)
#       1 def multiplot(title = None, ylabel = None,legend=True):
# ----> 2     ops.multiplot(datasets,provinces,title,ylabel,legend_on=legend)
#
# AttributeError: module 'operations' has no attribute 'multiplot'

# %%
datasets=["Percent Urban"]
multiplot()

# %%
datasets=["Total Resident Population"]
multiplot()

# %%
datasets=["Rural Population"]
multiplot()

# %%
datasets = ["Net Graduate Inflow"]
provinces = None
multiplot()

# %%
provinces=["Guangdong", "Zhejiang", "Jiangsu"]
multiplot()
